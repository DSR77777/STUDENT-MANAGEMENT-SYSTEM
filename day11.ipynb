# %%
f1=open("sample.txt",'r')
data=f1.read()
print(data)
f1.close()
# Out:
# hi hello

# %%
f2=open("sample.txt",'w')
f2.write("welcome")
f2.close()

# %%
f3=open("sample.txt",'a')
f3.write("Python programming")
f3.close()

# %%
f=open("program.txt",'w')
f.write("Python\nJava\nC\nC++")
f.close()

# %%
f1=open("program.txt",'r')
data=f1.read()
print(data)
f1.close()
# Out:
# Python
# Java
# C
# C++

# %%
f1=open("program.txt",'r')
data=f1.readline()
print(data)
f1.close()
# Out:
# Python

# %%
f1=open("program.txt",'r')
data=f1.readlines()
print(data)
f1.close()
# Out:
# ['Python\n', 'Java\n', 'C\n', 'C++']

# %%
#Function with return and arguments
def addition(n1,n2):
    s=n1+n2
    return s
result=addition(5,10)
print(result)
# Out:
# 15

# %%
#function with arguments without return
def addition(n1,n2):
    s=n1+n2
    print(s) # Combine two:print(n1+n2)
addition(45,5)
# Out:
# 50

# %%
#function with return without arguments
def addition():
    n1,n2=1,1
    return(n1+n2)
res=addition()
print(res)
# Out:
# 2

# %%
#function without return and arguments
def addition():
    n1,n2=3,3
    print(n1+n2)
addition()
# Out:
# 6

# %%
#find factorial of a given number using fucntion
def factorial(n):
    fact=1
    for i in range(1,n+1):
        fact=fact*i
    return fact
n=int(input("enter a number:"))
print("the factorial is:",factorial(n))
# Out:
# enter a number: 5
# the factorial is: 120

# %%
#sum of elements in a list using function
def Sum(l):
    s=0
    for i in l:
        s=s+i
    return s
l=[1,2,3,4,5]
print(sum(l)) #another way! res=sum(l) print(
# Out:
# 15

# %%
#STUDENT MANAGEMENT SYSTEM MENU
def menu():
    print("\nSTUDENT MANAGEMENT SYSTEM")
    print("1. Add Student")
    print("2. View Students")
    print("3. Search Student")
    print("4. Update Student")
    print("5. Delete Student")
    print("6. Statistics")
    print("7. Export Report")
    print("8. Exit")
 while True:
    menu()
    ch = int(input("Enter choice: "))

    if ch == 1:
        pass
    elif ch == 2:
        pass
    elif ch == 3:
        pass
    elif ch == 4:
        pass
    elif ch == 5:
        pass
    elif ch == 6:
        pass
    elif ch == 7:
        pass
    elif ch == 8:
        print("Thank You")
        break
    else:
        print("Invalid Choice")
